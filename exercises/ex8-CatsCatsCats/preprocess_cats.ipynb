# %%
from skimage import io
from skimage.util import img_as_ubyte
import matplotlib.pyplot as plt
import numpy as np
import glob
from sklearn.decomposition import PCA
from skimage.transform import SimilarityTransform
from skimage.transform import warp
import os
import pathlib

# %%
def read_landmark_file(file_name):
    f = open(file_name, 'r')
    lm_s = f.readline().strip().split(' ')
    n_lms = int(lm_s[0])
    if n_lms < 3:
        print(f"Not enough landmarks found")
        return None

    new_lms = 3
    # 3 landmarks each with (x,y)
    lm = np.zeros((new_lms, 2))
    for i in range(new_lms):
        lm[i, 0] = lm_s[1 + i * 2]
        lm[i, 1] = lm_s[2 + i * 2]
    return lm

# %%
def align_and_crop_one_cat_to_destination_cat(img_src, lm_src, img_dst, lm_dst):
    """
    Landmark based alignment of one cat image to a destination
    :param img_src: Image of source cat
    :param lm_src: Landmarks for source cat
    :param lm_dst: Landmarks for destination cat
    :return: Warped and cropped source image. None if something did not work
    """
    tform = SimilarityTransform()
    tform.estimate(lm_src, lm_dst)
    warped = warp(img_src, tform.inverse, output_shape=img_dst.shape)

    # Center of crop region
    cy = 185
    cx = 210
    # half the size of the crop box
    sz = 180
    warp_crop = warped[cy - sz:cy + sz, cx - sz:cx + sz]
    shape = warp_crop.shape
    if shape[0] == sz * 2 and shape[1] == sz * 2:
        return img_as_ubyte(warp_crop)
    else:
        print(f"Could not crop image. It has shape {shape}. Probably to close to border of image")
        return None

# %%
def preprocess_all_cats(in_dir, out_dir):
    """
    Create aligned and cropped version of image
    :param in_dir: Where are the original photos and landmark files
    :param out_dir: Where should the preprocessed files be placed
    """
    dst = "data/ModelCat"
    dst_lm = read_landmark_file(f"{dst}.jpg.cat")
    dst_img = io.imread(f"{dst}.jpg")

    all_images = glob.glob(in_dir + "*.jpg")
    for img_idx in all_images:
        name_no_ext = os.path.splitext(img_idx)[0]
        print(name_no_ext)
        base_name = os.path.basename(name_no_ext)
        out_name = f"{out_dir}/{base_name}_preprocessed.jpg"

        src_lm = read_landmark_file(f"{name_no_ext}.jpg.cat")
        src_img = io.imread(f"{name_no_ext}.jpg")

        proc_img = align_and_crop_one_cat_to_destination_cat(src_img, src_lm, dst_img, dst_lm)
        if proc_img is not None:
            io.imsave(out_name, proc_img)

# %%
def preprocess_one_cat():
    src = "data/MissingCat"
    dst = "data/ModelCat"
    out = "data/MissingCatProcessed.jpg"

    src_lm = read_landmark_file(f"{src}.jpg.cat")
    dst_lm = read_landmark_file(f"{dst}.jpg.cat")

    src_img = io.imread(f"{src}.jpg")
    dst_img = io.imread(f"{dst}.jpg")

    src_proc = align_and_crop_one_cat_to_destination_cat(src_img, src_lm, dst_img, dst_lm)
    if src_proc is None:
        return

    io.imsave(out, src_proc)

    fig, ax = plt.subplots(ncols=3, figsize=(16, 6))
    ax[0].imshow(src_img)
    ax[0].plot(src_lm[:, 0], src_lm[:, 1], '.r', markersize=12)
    ax[1].imshow(dst_img)
    ax[1].plot(dst_lm[:, 0], dst_lm[:, 1], '.r', markersize=12)
    ax[2].imshow(src_proc)
    for a in ax:
        a.axis('off')
    plt.tight_layout()
    plt.show()

# %%
def create_u_byte_image_from_vector(im_vec, height, width, channels):
    min_val = im_vec.min()
    max_val = im_vec.max()

    # Transform to [0, 1]
    im_vec = np.subtract(im_vec, min_val)
    im_vec = np.divide(im_vec, max_val - min_val)
    im_vec = im_vec.reshape(height, width, channels)
    im_out = img_as_ubyte(im_vec)
    return im_out

# %%
preprocess_all_cats("training_data/training_data_100/", "training_data/preprocessed/")
# Out:
# 100
# training_data/training_data_100/00000007_015
# training_data/training_data_100/00000009_005
# training_data/training_data_100/00000003_024
# training_data/training_data_100/00000001_000
# training_data/training_data_100/00000006_011
# training_data/training_data_100/00000004_012
# training_data/training_data_100/00000003_015
# training_data/training_data_100/00000001_029
# training_data/training_data_100/00000011_001
# training_data/training_data_100/00000005_017
# training_data/training_data_100/00000005_022
# training_data/training_data_100/00000009_013
# training_data/training_data_100/00000010_003
# training_data/training_data_100/00000011_010
# training_data/training_data_100/00000012_025
# training_data/training_data_100/00000010_029
# training_data/training_data_100/00000004_003
# training_data/training_data_100/00000011_023
# training_data/training_data_100/00000009_015
# training_data/training_data_100/00000008_029
# training_data/training_data_100/00000001_017
# training_data/training_data_100/00000006_016
# training_data/training_data_100/00000006_029
# training_data/training_data_100/00000007_008
# training_data/training_data_100/00000004_023
# training_data/training_data_100/00000006_024
# training_data/training_data_100/00000009_004
# training_data/training_data_100/00000011_025
# training_data/training_data_100/00000011_002
# training_data/training_data_100/00000011_004
# training_data/training_data_100/00000001_005
# training_data/training_data_100/00000002_003
# training_data/training_data_100/00000012_022
# training_data/training_data_100/00000006_013
# training_data/training_data_100/00000009_009
# training_data/training_data_100/00000011_017
# training_data/training_data_100/00000010_006
# training_data/training_data_100/00000002_001
# training_data/training_data_100/00000009_023
# training_data/training_data_100/00000006_025
# training_data/training_data_100/00000006_009
# training_data/training_data_100/00000009_016
# training_data/training_data_100/00000009_026
# training_data/training_data_100/00000001_008
# training_data/training_data_100/00000001_024
# training_data/training_data_100/00000007_012
# training_data/training_data_100/00000001_020
# training_data/training_data_100/00000005_001
# training_data/training_data_100/00000010_027
# training_data/training_data_100/00000009_003
# training_data/training_data_100/00000003_009
# training_data/training_data_100/00000007_004
# training_data/training_data_100/00000001_016
# training_data/training_data_100/00000004_008
# training_data/training_data_100/00000004_007
# training_data/training_data_100/00000005_020
# training_data/training_data_100/00000006_008
# training_data/training_data_100/00000011_015
# training_data/training_data_100/00000001_027
# training_data/training_data_100/00000003_026
# training_data/training_data_100/00000007_002
# training_data/training_data_100/00000007_022
# training_data/training_data_100/00000001_012
# training_data/training_data_100/00000007_013
# training_data/training_data_100/00000008_028
# training_data/training_data_100/00000003_012
# training_data/training_data_100/00000012_010
# training_data/training_data_100/00000008_018
# training_data/training_data_100/00000011_014
# training_data/training_data_100/00000011_020
# training_data/training_data_100/00000002_026
# training_data/training_data_100/00000003_029
# training_data/training_data_100/00000005_023
# training_data/training_data_100/00000003_007
# training_data/training_data_100/00000004_028
# training_data/training_data_100/00000007_007
# training_data/training_data_100/00000011_003
# training_data/training_data_100/00000011_027
# training_data/training_data_100/00000005_000
# training_data/training_data_100/00000008_003
# training_data/training_data_100/00000007_014
# training_data/training_data_100/00000011_016
# training_data/training_data_100/00000004_018
# training_data/training_data_100/00000006_006
# training_data/training_data_100/00000009_022
# training_data/training_data_100/00000010_028
# training_data/training_data_100/00000007_005
# training_data/training_data_100/00000002_008
# training_data/training_data_100/00000006_022
# training_data/training_data_100/00000010_000
# training_data/training_data_100/00000011_007
# training_data/training_data_100/00000003_013
# training_data/training_data_100/00000005_012
# training_data/training_data_100/00000009_021
# training_data/training_data_100/00000007_006
# training_data/training_data_100/00000008_007
# training_data/training_data_100/00000001_011
# training_data/training_data_100/00000007_000
# training_data/training_data_100/00000003_020
# training_data/training_data_100/00000008_002
